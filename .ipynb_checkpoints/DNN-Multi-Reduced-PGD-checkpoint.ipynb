# %%
# !rm -rf '/content/DIS_Hughen'
# !git clone https://github.com/NU-Academics/DIS_Hughen.git

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shap
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.manifold import TSNE
from sklearn.metrics import  accuracy_score, classification_report, confusion_matrix, f1_score, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from torch.utils.data import TensorDataset, DataLoader

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
df = pd.read_csv("undersampled_CIC2019_dataset.csv")
# df = pd.read_csv("/content/DIS_Hughen/undersampled_CIC2019_dataset.csv")

# %%
df.shape
# Out:
# (4685611, 90)

# %%
df["label"].value_counts()
# Out:
# label
# TFTP             950295
# DrDoS_NTP        917607
# DrDoS_DNS        893762
# DrDoS_SNMP       415000
# DrDoS_LDAP       290000
# LDAP             290000
# MSSQL            190000
# UDP              150000
# DrDoS_MSSQL      150000
# DrDoS_SSDP       106650
# DrDoS_UDP        105000
# DrDoS_NetBIOS     65000
# NetBIOS           55057
# BENIGN            53277
# Syn               42004
# Portmap            5608
# UDP-lag            5000
# UDPLag             1203
# WebDDoS             148
# Name: count, dtype: int64

# %%
dos_set = df[df["label"].str.contains("DoS", case=False, na=False)]
dos_sample = (dos_set.sample(n=50000, random_state=42, replace=False).reset_index(drop=True))
dos_sample["label"] = "DoS_ATTACK"
dos_sample["label"].value_counts()
# Out:
# label
# DoS_ATTACK    50000
# Name: count, dtype: int64

# %%
non_dos_set = df[(df["label"] != "BENIGN") & (~df["label"].str.contains("DoS", case=False, na=False))]
non_dos_sample = (non_dos_set.sample(n=50000, random_state=42, replace=False).reset_index(drop=True))
non_dos_sample["label"] = "NON_DoS_ATTACK"
non_dos_sample["label"].value_counts()
# Out:
# label
# NON_DoS_ATTACK    50000
# Name: count, dtype: int64

# %%
attack_sample =pd.concat([dos_sample, non_dos_sample]).reset_index(drop=True)
attack_sample["label"].value_counts()
# Out:
# label
# DoS_ATTACK        50000
# NON_DoS_ATTACK    50000
# Name: count, dtype: int64

# %%
benign_set = df[df["label"] == "BENIGN"]
benign_sample = benign_set.sample(n=non_dos_sample.shape[0], replace=False, random_state=42)

# %%
benign_sample.shape
# Out:
# (50000, 90)

# %%
print(benign_sample["label"].value_counts())
# Out:
# label
# BENIGN    50000
# Name: count, dtype: int64

# %%
df_sample =pd.concat([benign_sample, attack_sample]).reset_index(drop=True)

# %%
df_sample.shape
# Out:
# (150000, 90)

# %%
df_sample["label"].value_counts()
# Out:
# label
# BENIGN            50000
# DoS_ATTACK        50000
# NON_DoS_ATTACK    50000
# Name: count, dtype: int64

# %%
le = LabelEncoder()
df_sample["label"] = le.fit_transform(df_sample["label"])
X = df_sample.drop(columns=["label"], errors="ignore").select_dtypes(include=[np.number])
X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.fillna(0, inplace=True)
y = df_sample["label"]
label_mapping = dict(zip(le.classes_, range(len(le.classes_))))
print(label_mapping)
# Out:
# {'BENIGN': 0, 'DoS_ATTACK': 1, 'NON_DoS_ATTACK': 2}

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y # 0.2
)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train.values, dtype=torch.long)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val.values, dtype=torch.long)

train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=2048, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=2048)

# %%
input_size = 88
hidden_size = 128
num_classes = 3

class MultiClassDNN(nn.Module):
    def __init__(self, input_size=88, num_classes=3):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 128), #256
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.BatchNorm1d(64),
            nn.ReLU(),
#            nn.Dropout(0.3),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )
    def forward(self, x):
        return self.net(x)

# %%
model = MultiClassDNN().to(device)
criterion = nn.CrossEntropyLoss(label_smoothing=0.05)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)

# %%
num_epochs = 100
train_losses = []
val_losses = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        logits = model(X_batch)
        loss = criterion(logits, y_batch)
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        train_loss += loss.item() * X_batch.size(0)
    avg_train_loss = train_loss / len(train_loader.dataset)
    train_losses.append(avg_train_loss)
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            logits = model(X_batch)
            loss = criterion(logits, y_batch)
            val_loss += loss.item() * X_batch.size(0)
    avg_val_loss = val_loss / len(val_loader.dataset)
    val_losses.append(avg_val_loss)
    print(f"Epoch {epoch+1}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")
    
torch.save(model.state_dict(), "multiclass_dnn.pth")
# Out:
# Epoch 1, Train Loss: 0.6427, Val Loss: 0.3946
# Epoch 2, Train Loss: 0.3804, Val Loss: 0.3696
# Epoch 3, Train Loss: 0.3714, Val Loss: 0.3665
# Epoch 4, Train Loss: 0.3685, Val Loss: 0.3651
# Epoch 5, Train Loss: 0.3667, Val Loss: 0.3634
# Epoch 6, Train Loss: 0.3654, Val Loss: 0.3620
# Epoch 7, Train Loss: 0.3639, Val Loss: 0.3611
# Epoch 8, Train Loss: 0.3627, Val Loss: 0.3602
# Epoch 9, Train Loss: 0.3620, Val Loss: 0.3596
# Epoch 10, Train Loss: 0.3615, Val Loss: 0.3611
# Epoch 11, Train Loss: 0.3609, Val Loss: 0.3600
# Epoch 12, Train Loss: 0.3600, Val Loss: 0.3584
# Epoch 13, Train Loss: 0.3592, Val Loss: 0.3594
# Epoch 14, Train Loss: 0.3595, Val Loss: 0.3577
# Epoch 15, Train Loss: 0.3589, Val Loss: 0.3581
# Epoch 16, Train Loss: 0.3595, Val Loss: 0.3576
# Epoch 17, Train Loss: 0.3585, Val Loss: 0.3574
# Epoch 18, Train Loss: 0.3580, Val Loss: 0.3580
# Epoch 19, Train Loss: 0.3577, Val Loss: 0.3568
# Epoch 20, Train Loss: 0.3573, Val Loss: 0.3585
# Epoch 21, Train Loss: 0.3578, Val Loss: 0.3564
# Epoch 22, Train Loss: 0.3573, Val Loss: 0.3568
# Epoch 23, Train Loss: 0.3571, Val Loss: 0.3564
# Epoch 24, Train Loss: 0.3575, Val Loss: 0.3563
# Epoch 25, Train Loss: 0.3571, Val Loss: 0.3568
# Epoch 26, Train Loss: 0.3566, Val Loss: 0.3562
# Epoch 27, Train Loss: 0.3570, Val Loss: 0.3566
# Epoch 28, Train Loss: 0.3566, Val Loss: 0.3564
# Epoch 29, Train Loss: 0.3564, Val Loss: 0.3564
# Epoch 30, Train Loss: 0.3566, Val Loss: 0.3569
# Epoch 31, Train Loss: 0.3564, Val Loss: 0.3557
# Epoch 32, Train Loss: 0.3559, Val Loss: 0.3557
# Epoch 33, Train Loss: 0.3554, Val Loss: 0.3561
# Epoch 34, Train Loss: 0.3559, Val Loss: 0.3555
# Epoch 35, Train Loss: 0.3557, Val Loss: 0.3561
# Epoch 36, Train Loss: 0.3557, Val Loss: 0.3558
# Epoch 37, Train Loss: 0.3554, Val Loss: 0.3552
# Epoch 38, Train Loss: 0.3556, Val Loss: 0.3557
# Epoch 39, Train Loss: 0.3556, Val Loss: 0.3553
# Epoch 40, Train Loss: 0.3556, Val Loss: 0.3567
# Epoch 41, Train Loss: 0.3557, Val Loss: 0.3555
# Epoch 42, Train Loss: 0.3554, Val Loss: 0.3554
# Epoch 43, Train Loss: 0.3553, Val Loss: 0.3552
# Epoch 44, Train Loss: 0.3549, Val Loss: 0.3560
# Epoch 45, Train Loss: 0.3551, Val Loss: 0.3553
# Epoch 46, Train Loss: 0.3554, Val Loss: 0.3553
# Epoch 47, Train Loss: 0.3551, Val Loss: 0.3558
# Epoch 48, Train Loss: 0.3551, Val Loss: 0.3551
# Epoch 49, Train Loss: 0.3552, Val Loss: 0.3554
# Epoch 50, Train Loss: 0.3551, Val Loss: 0.3564
# Epoch 51, Train Loss: 0.3552, Val Loss: 0.3555
# Epoch 52, Train Loss: 0.3547, Val Loss: 0.3548
# Epoch 53, Train Loss: 0.3551, Val Loss: 0.3552
# Epoch 54, Train Loss: 0.3550, Val Loss: 0.3550
# Epoch 55, Train Loss: 0.3546, Val Loss: 0.3551
# Epoch 56, Train Loss: 0.3548, Val Loss: 0.3549
# Epoch 57, Train Loss: 0.3554, Val Loss: 0.3553
# Epoch 58, Train Loss: 0.3555, Val Loss: 0.3552
# Epoch 59, Train Loss: 0.3551, Val Loss: 0.3563
# Epoch 60, Train Loss: 0.3553, Val Loss: 0.3550
# Epoch 61, Train Loss: 0.3551, Val Loss: 0.3567
# Epoch 62, Train Loss: 0.3546, Val Loss: 0.3548
# Epoch 63, Train Loss: 0.3547, Val Loss: 0.3556
# Epoch 64, Train Loss: 0.3550, Val Loss: 0.3550
# Epoch 65, Train Loss: 0.3547, Val Loss: 0.3554
# Epoch 66, Train Loss: 0.3545, Val Loss: 0.3551
# Epoch 67, Train Loss: 0.3547, Val Loss: 0.3554
# Epoch 68, Train Loss: 0.3548, Val Loss: 0.3562
# Epoch 69, Train Loss: 0.3548, Val Loss: 0.3547
# Epoch 70, Train Loss: 0.3548, Val Loss: 0.3555
# Epoch 71, Train Loss: 0.3544, Val Loss: 0.3555
# Epoch 72, Train Loss: 0.3547, Val Loss: 0.3549
# Epoch 73, Train Loss: 0.3544, Val Loss: 0.3554
# Epoch 74, Train Loss: 0.3543, Val Loss: 0.3549
# Epoch 75, Train Loss: 0.3543, Val Loss: 0.3545
# Epoch 76, Train Loss: 0.3542, Val Loss: 0.3548
# Epoch 77, Train Loss: 0.3547, Val Loss: 0.3558
# Epoch 78, Train Loss: 0.3549, Val Loss: 0.3549
# Epoch 79, Train Loss: 0.3546, Val Loss: 0.3552
# Epoch 80, Train Loss: 0.3552, Val Loss: 0.3551
# Epoch 81, Train Loss: 0.3551, Val Loss: 0.3550
# Epoch 82, Train Loss: 0.3547, Val Loss: 0.3548
# Epoch 83, Train Loss: 0.3547, Val Loss: 0.3547
# Epoch 84, Train Loss: 0.3543, Val Loss: 0.3551
# Epoch 85, Train Loss: 0.3547, Val Loss: 0.3546
# Epoch 86, Train Loss: 0.3567, Val Loss: 0.3554
# Epoch 87, Train Loss: 0.3546, Val Loss: 0.3561
# Epoch 88, Train Loss: 0.3546, Val Loss: 0.3549
# Epoch 89, Train Loss: 0.3543, Val Loss: 0.3543
# Epoch 90, Train Loss: 0.3543, Val Loss: 0.3548
# Epoch 91, Train Loss: 0.3546, Val Loss: 0.3549
# Epoch 92, Train Loss: 0.3557, Val Loss: 0.3551
# Epoch 93, Train Loss: 0.3557, Val Loss: 0.3555
# Epoch 94, Train Loss: 0.3549, Val Loss: 0.3550
# Epoch 95, Train Loss: 0.3554, Val Loss: 0.3552
# Epoch 96, Train Loss: 0.3557, Val Loss: 0.3548
# Epoch 97, Train Loss: 0.3549, Val Loss: 0.3547
# Epoch 98, Train Loss: 0.3544, Val Loss: 0.3548
# Epoch 99, Train Loss: 0.3543, Val Loss: 0.3546
# Epoch 100, Train Loss: 0.3546, Val Loss: 0.3547

# %%
plt.figure()
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
model.eval()
X_tensor = X_val_tensor.to(device)
y = y_val.values
with torch.no_grad():
    logits = model(X_tensor)
    y_prob = torch.softmax(logits, dim=1).cpu().numpy()
    y_pred = np.argmax(y_prob, axis=1)

# %%
print("Accuracy:", accuracy_score(y, y_pred))
print("Weighted F1:", f1_score(y, y_pred, average='weighted'))
print("Macro F1:", f1_score(y, y_pred, average='macro'))
print("ROC-AUC:", roc_auc_score(y, y_prob, multi_class="ovr", average="weighted"))
# Out:
# Accuracy: 0.891
# Weighted F1: 0.8909501685759613
# Macro F1: 0.8909501685759614
# ROC-AUC: 0.9711517696296297

# %%
print(classification_report(y, y_pred, target_names=le.classes_))
# Out:
#                 precision    recall  f1-score   support
#
#         BENIGN       1.00      1.00      1.00     15000
#     DoS_ATTACK       0.83      0.85      0.84     15000
# NON_DoS_ATTACK       0.85      0.82      0.83     15000
#
#       accuracy                           0.89     45000
#      macro avg       0.89      0.89      0.89     45000
#   weighted avg       0.89      0.89      0.89     45000

# %%
def pgd_attack(model, X, y, epsilon, alpha=0.001, num_steps=100, random_start=True):
    model.eval()
    X = torch.tensor(np.array(X), dtype=torch.float32, device=device)
    y = torch.tensor(np.array(y), dtype=torch.long, device=device)
    x_min = X.min()
    x_max = X.max()
    if random_start:
        delta = torch.empty_like(X).uniform_(-epsilon, epsilon)
    else:
        delta = torch.zeros_like(X)
    delta = delta.to(device)
    for _ in range(num_steps):
        delta.requires_grad_(True)
        X_adv = torch.clamp(X + delta, x_min, x_max)
        outputs = model(X_adv)
        loss = F.cross_entropy(outputs, y)
        model.zero_grad(set_to_none=True)
        if delta.grad is not None:
            delta.grad.zero_()
        loss.backward()
        grad = delta.grad.detach()
        delta = delta + alpha * torch.sign(grad)
        delta = torch.clamp(delta, -epsilon, epsilon)
        delta = torch.clamp(X + delta, x_min, x_max) - X
        delta = delta.detach()
    X_adv = torch.clamp(X + delta, x_min, x_max)
    return X_adv.detach().cpu().numpy()

# %%
def epsilon_eval(epsilon):
    X_train_adv = pgd_attack(model, X_train, y_train, epsilon)
    X_val_adv   = pgd_attack(model, X_val, y_val, epsilon)
    model.eval()
    X_tensor = torch.tensor(X_val_adv, dtype=torch.float32).to(device)
    with torch.no_grad():
        outputs = model(X_tensor)
        y_pred_adv = torch.argmax(outputs, dim=1).cpu().numpy()
    print("=== ADVERSARIAL DATA ===")
    print("Epsilon:", epsilon)
    print("Accuracy:", accuracy_score(y_val, y_pred_adv))
    print(classification_report(y_val, y_pred_adv))

for epsilon in [0.01, 0.05, 0.1, 0.5]:
    epsilon_eval(epsilon)
# Out:
# === ADVERSARIAL DATA ===
# Epsilon: 0.01
# Accuracy: 0.8878444444444444
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15000
#            1       0.82      0.85      0.83     15000
#            2       0.84      0.81      0.83     15000
#
#     accuracy                           0.89     45000
#    macro avg       0.89      0.89      0.89     45000
# weighted avg       0.89      0.89      0.89     45000
#
# === ADVERSARIAL DATA ===
# Epsilon: 0.05
# Accuracy: 0.7645111111111111
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15000
#            1       0.66      0.61      0.63     15000
#            2       0.64      0.69      0.66     15000
#
#     accuracy                           0.76     45000
#    macro avg       0.77      0.76      0.76     45000
# weighted avg       0.77      0.76      0.76     45000
#
# === ADVERSARIAL DATA ===
# Epsilon: 0.1
# Accuracy: 0.7383333333333333
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15000
#            1       0.62      0.58      0.60     15000
#            2       0.60      0.64      0.62     15000
#
#     accuracy                           0.74     45000
#    macro avg       0.74      0.74      0.74     45000
# weighted avg       0.74      0.74      0.74     45000
#
# === ADVERSARIAL DATA ===
# Epsilon: 0.5
# Accuracy: 0.6818222222222222
#               precision    recall  f1-score   support
#
#            0       0.99      0.94      0.97     15000
#            1       0.54      0.58      0.56     15000
#            2       0.54      0.53      0.53     15000
#
#     accuracy                           0.68     45000
#    macro avg       0.69      0.68      0.69     45000
# weighted avg       0.69      0.68      0.69     45000
